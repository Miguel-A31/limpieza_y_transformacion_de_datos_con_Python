# %%
import pandas as pd
import numpy as np

# %%
df_Airbnb = pd.read_csv('Airbnb_Open_Data.csv')
df_Airbnb.head(3)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16580\308173643.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Airbnb = pd.read_csv('Airbnb_Open_Data.csv')
#         id                                 NAME      host id  \
# 0  1001254   Clean & quiet apt home by the park  80014485718
# 1  1002102                Skylit Midtown Castle  52335172823
# 2  1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
#
# [3 rows x 26 columns]

# %%
df_Airbnb.dtypes.sort_values(ascending=False)
# Out:
# room type                          object
# country code                       object
# house_rules                        object
# last review                        object
# service fee                        object
# price                              object
# NAME                               object
# cancellation_policy                object
# instant_bookable                   object
# license                            object
# country                            object
# neighbourhood                      object
# neighbourhood group                object
# host name                          object
# host_identity_verified             object
# long                              float64
# lat                               float64
# Construction year                 float64
# minimum nights                    float64
# number of reviews                 float64
# reviews per month                 float64
# review rate number                float64
# calculated host listings count    float64
# availability 365                  float64
# host id                             int64
# id                                  int64
# dtype: object

# %%
df_Airbnb.isnull().sum().sort_values(ascending=False)
# Out:
# license                           102597
# house_rules                        52131
# last review                        15893
# reviews per month                  15879
# country                              532
# availability 365                     448
# minimum nights                       409
# host name                            406
# review rate number                   326
# calculated host listings count       319
# host_identity_verified               289
# service fee                          273
# NAME                                 250
# price                                247
# Construction year                    214
# number of reviews                    183
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# neighbourhood group                   29
# neighbourhood                         16
# long                                   8
# lat                                    8
# id                                     0
# host id                                0
# room type                              0
# dtype: int64

# %% [markdown]
# **Count missing values in each column**
#
# Using a for loop in Python, we can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value and "False" means the value is present in the dataset. In the body of the for loop the method ".value_counts()" counts the number of "True" values.

# %%
# pero primero vamos a guardar los datos faltantes en una variable
missing_data = df_Airbnb.isnull()
missing_data.head()
# Out:
#       id   NAME  host id  host_identity_verified  host name  \
# 0  False  False    False                   False      False
# 1  False  False    False                   False      False
# 2  False  False    False                    True      False
# 3  False   True    False                   False      False
# 4  False  False    False                   False      False
#
#    neighbourhood group  neighbourhood    lat   long  country  ...  \
# 0                False          False  False  False    False  ...
# 1                False          False  False  False    False  ...
# 2                False          False  False  False    False  ...
# 3                False          False  False  False    False  ...
# 4                False          False  False  False    False  ...
#
#    service fee  minimum nights  number of reviews  last review  \
# 0        False           False              False        False
# 1        False           False              False        False
# 2        False           False              False         True
# 3        False           False              False        False
# 4        False           False              False        False
#
#    reviews per month  review rate number  calculated host listings count  \
# 0              False               False                           False
# 1              False               False                           False
# 2               True               False                           False
# 3              False               False                           False
# 4              False               False                           False
#
#    availability 365  house_rules  license
# 0             False        False     True
# 1             False        False     True
# 2             False        False     True
# 3             False         True     True
# 4             False        False     True
#
# [5 rows x 26 columns]

# %%
for column in missing_data:
    print(f'Columna: {column}')
    print(missing_data[column].value_counts().sort_index(ascending=False))
    print("")
# Out:
# Columna: id
# False    102599
# Name: id, dtype: int64
#
# Columna: NAME
# True        250
# False    102349
# Name: NAME, dtype: int64
#
# Columna: host id
# False    102599
# Name: host id, dtype: int64
#
# Columna: host_identity_verified
# True        289
# False    102310
# Name: host_identity_verified, dtype: int64
#
# Columna: host name
# True        406
# False    102193
# Name: host name, dtype: int64
#
# Columna: neighbourhood group
# True         29
# False    102570
# Name: neighbourhood group, dtype: int64
#
# Columna: neighbourhood
# True         16
# False    102583
# Name: neighbourhood, dtype: int64
#
# Columna: lat
# True          8
# False    102591
# Name: lat, dtype: int64
#
# Columna: long
# True          8
# False    102591
# Name: long, dtype: int64
#
# Columna: country
# True        532
# False    102067
# Name: country, dtype: int64
#
# Columna: country code
# True        131
# False    102468
# Name: country code, dtype: int64
#
# Columna: instant_bookable
# True        105
# False    102494
# Name: instant_bookable, dtype: int64
#
# Columna: cancellation_policy
# True         76
# False    102523
# Name: cancellation_policy, dtype: int64
#
# Columna: room type
# False    102599
# Name: room type, dtype: int64
#
# Columna: Construction year
# True        214
# False    102385
# Name: Construction year, dtype: int64
#
# Columna: price
# True        247
# False    102352
# Name: price, dtype: int64
#
# Columna: service fee
# True        273
# False    102326
# Name: service fee, dtype: int64
#
# Columna: minimum nights
# True        409
# False    102190
# Name: minimum nights, dtype: int64
#
# Columna: number of reviews
# True        183
# False    102416
# Name: number of reviews, dtype: int64
#
# Columna: last review
# True     15893
# False    86706
# Name: last review, dtype: int64
#
# Columna: reviews per month
# True     15879
# False    86720
# Name: reviews per month, dtype: int64
#
# Columna: review rate number
# True        326
# False    102273
# Name: review rate number, dtype: int64
#
# Columna: calculated host listings count
# True        319
# False    102280
# Name: calculated host listings count, dtype: int64
#
# Columna: availability 365
# True        448
# False    102151
# Name: availability 365, dtype: int64
#
# Columna: house_rules
# True     52131
# False    50468
# Name: house_rules, dtype: int64
#
# Columna: license
# True     102597
# False         2
# Name: license, dtype: int64

# %% [markdown]
# # Deal with missing data

# %% [markdown]
# vamos a lidear con los datos faltantes de forma descendente y en el proceso se va explorando los datos.

# %%
# como vemos la columna 'license' tiene 102597 datos faltantes y solo 2 datos reales por lo que no aporta mucha información
df_Airbnb.loc[~df_Airbnb.license.isnull()]
# Out:
#              id                                NAME      host id  \
# 11114   7139598  Cozy 1 BR on Bedford Avenue, Wburg  73023181304
# 72947  41289964  Cozy 1 BR on Bedford Avenue, Wburg  25804773951
#
#       host_identity_verified  host name neighbourhood group neighbourhood  \
# 11114               verified  Christina            Brooklyn  Williamsburg
# 72947            unconfirmed  Christina            Brooklyn  Williamsburg
#
#             lat      long        country  ... service fee minimum nights  \
# 11114  40.71764 -73.95689  United States  ...       $140             1.0
# 72947  40.71764 -73.95689  United States  ...       $140             1.0
#
#       number of reviews last review  reviews per month review rate number  \
# 11114               1.0    1/3/2016               0.02                1.0
# 72947               1.0    1/3/2016               0.02                1.0
#
#       calculated host listings count  availability 365  \
# 11114                            1.0             191.0
# 72947                            1.0               0.0
#
#                                              house_rules   license
# 11114  Dear Guest, Thank you for appreciating that I ...  41662/AL
# 72947                                                NaN  41662/AL
#
# [2 rows x 26 columns]

# %%
# Es preciso entonces eliminar esta columna
df_Airbnb.drop('license', axis=1, inplace =True)

# %%
# como la mayoria se trata de describir como son reglas y 
# presenta valores faltantes podemos reemplazar estos valores por 'Empty' 
# no se elimina 'house_rules' porque puede ser una variable predictora del precio

df_Airbnb.loc[df_Airbnb.house_rules.isnull(), 'house_rules'] = 'Empty'

# %%
# vemos que la variable 'last review' es de tipo cadena lo mejor es convertir a tipo fecha y poder trabajer mejor
df_Airbnb['last review']
# Out:
# 0         10/19/2021
# 1          5/21/2022
# 2                NaN
# 3           7/5/2019
# 4         11/19/2018
#              ...
# 102594           NaN
# 102595      7/6/2015
# 102596           NaN
# 102597    10/11/2015
# 102598           NaN
# Name: last review, Length: 102599, dtype: object

# %%
df_Airbnb['last review'] = pd.to_datetime(df_Airbnb['last review'])

# %%
# comprobamos las marcas de tiempo de principio a fin 
df_Airbnb['last review']. min(), df_Airbnb['last review']. max()
# Out:
# (Timestamp('2012-07-11 00:00:00'), Timestamp('2058-06-16 00:00:00'))

# %%
# se puede ver que la variable 'last review' muestra fechas falsas 
df_Airbnb[df_Airbnb['last review'].apply(lambda x: x.year) > 2023]
# Out:
#           id                                  NAME      host id  \
# 127  1071478   Garden studio in the Upper East Sid  77172555024
# 191  1106825  LUX APT IN TIMES SQUARE NEW BUILDING  93725364475
# 255  1142173           Beautiful Landmarked Duplex  87944779917
# 318  1176967                                   NaN  70084472212
# 483  1268097      Modern Space in Charming Pre-war  13746585241
#
#     host_identity_verified host name neighbourhood group    neighbourhood  \
# 127            unconfirmed    Miller           Manhattan  Upper East Side
# 191            unconfirmed     Aiden           Manhattan   Hell's Kitchen
# 255                    NaN     Baker            Brooklyn       Greenpoint
# 318               verified    Barnes            Brooklyn       Greenpoint
# 483               verified  Adelaide           Manhattan           Harlem
#
#           lat      long        country  ...  price service fee minimum nights  \
# 127  40.77800 -73.94822  United States  ...  $571        $114             5.0
# 191  40.76307 -73.99665  United States  ...  $539        $108             NaN
# 255  40.72945 -73.95511  United States  ...  $842        $168             3.0
# 318  40.72488 -73.95018  United States  ...  $920        $184             2.0
# 483  40.82411 -73.94934  United States  ...  $721        $144             2.0
#
#     number of reviews  last review reviews per month review rate number  \
# 127              21.0   2024-08-15              0.19                4.0
# 191              41.0   2025-06-26              0.38                2.0
# 255             124.0   2058-06-16              1.22                4.0
# 318               1.0   2026-03-28              0.01                3.0
# 483              41.0   2040-06-16              0.43                3.0
#
#      calculated host listings count  availability 365  \
# 127                             NaN             395.0
# 191                             1.0               NaN
# 255                             3.0             230.0
# 318                             1.0              73.0
# 483                             2.0              47.0
#
#                                            house_rules
# 127  Dear Guests, Welcome to 62 Cornwall St! I hope...
# 191  You will be sharing a bathroom, so you must be...
# 255  No rules per say. I just ask that you respect ...
# 318  Check-In is 3pm.  Check-Out is 12 Noon.  In or...
# 483                                              Empty
#
# [5 rows x 25 columns]

# %%
# ahora vamos arreglar los datos faltantes reemplando por la medina
df_Airbnb.loc[df_Airbnb['last review'].isnull(), 'last review'] = df_Airbnb['last review'].median()

# %%
# vamos observar la cantidad de duplicados
df_Airbnb.duplicated().sum()
# Out:
# 541

# %%
# observamos que hay 541 duplicados, sera mejor eliminarlos

df_Airbnb.drop_duplicates(keep='first', inplace=True)

# %%
df_Airbnb.duplicated(subset=['host name', 'lat', 'long', 'price']).sum()
# Out:
# 32753

# %%
sub_df_Airbnb = df_Airbnb.loc[df_Airbnb.duplicated(subset=['host name', 'lat', 'long', 'price'], keep=False)].copy()
sub_df_Airbnb = sub_df_Airbnb.groupby(['host name', 'lat', 'long', 'price'])
for key, subdf in sub_df_Airbnb:
    print(key)
    print(pd.DataFrame(subdf), '\n')
    break
# Out:
# ('(Ari) HENRY LEE', 40.78938, -73.94679, '$1,179 ')
#              id               NAME      host id host_identity_verified  \
# 10316   6698863  MANHATTAN LIVING!  47503557541               verified
# 72149  40849229  MANHATTAN LIVING!  29667285224               verified
#
#              host name neighbourhood group neighbourhood       lat      long  \
# 10316  (Ari) HENRY LEE           Manhattan   East Harlem  40.78938 -73.94679
# 72149  (Ari) HENRY LEE           Manhattan   East Harlem  40.78938 -73.94679
#
#              country  ...    price service fee minimum nights  \
# 10316  United States  ...  $1,179        $236             7.0
# 72149  United States  ...  $1,179        $236             7.0
#
#       number of reviews  last review reviews per month review rate number  \
# 10316               3.0   2017-12-08              0.06                1.0
# 72149               3.0   2017-12-08              0.06                1.0
#
#        calculated host listings count  availability 365 house_rules
# 10316                             1.0             403.0       Empty
# 72149                             1.0              56.0       Empty
#
# [2 rows x 25 columns]

# %%
del sub_df_Airbnb, subdf
df_Airbnb.drop_duplicates(subset=['host name', 'lat', 'long', 'price'], inplace=True)
df_Airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69305 entries, 0 to 102050
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              69305 non-null  int64
#  1   NAME                            69097 non-null  object
#  2   host id                         69305 non-null  int64
#  3   host_identity_verified          69088 non-null  object
#  4   host name                       68992 non-null  object
#  5   neighbourhood group             69276 non-null  object
#  6   neighbourhood                   69289 non-null  object
#  7   lat                             69297 non-null  float64
#  8   long                            69297 non-null  float64
#  9   country                         68982 non-null  object
#  10  country code                    69219 non-null  object
#  11  instant_bookable                69219 non-null  object
#  12  cancellation_policy             69248 non-null  object
#  13  room type                       69305 non-null  object
#  14  Construction year               69115 non-null  float64
#  15  price                           69060 non-null  object
#  16  service fee                     69064 non-null  object
#  17  minimum nights                  68942 non-null  float64
#  18  number of reviews               69153 non-null  float64
#  19  last review                     69305 non-null  datetime64[ns]
#  20  reviews per month               58491 non-null  float64
#  21  review rate number              69066 non-null  float64
#  22  calculated host listings count  69161 non-null  float64
#  23  availability 365                68867 non-null  float64
#  24  house_rules                     69305 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(13)
# memory usage: 13.7+ MB

# %%
# necesitamos saber la variabilidad de los datos
df_Airbnb.isnull().sum().sort_values(ascending=False)
# Out:
# reviews per month                 10814
# availability 365                    438
# minimum nights                      363
# country                             323
# host name                           313
# price                               245
# service fee                         241
# review rate number                  239
# host_identity_verified              217
# NAME                                208
# Construction year                   190
# number of reviews                   152
# calculated host listings count      144
# country code                         86
# instant_bookable                     86
# cancellation_policy                  57
# neighbourhood group                  29
# neighbourhood                        16
# long                                  8
# lat                                   8
# id                                    0
# last review                           0
# room type                             0
# host id                               0
# house_rules                           0
# dtype: int64

# %%
df_Airbnb.nunique().sort_values(ascending = False)
# Out:
# id                                69305
# host id                           69304
# NAME                              61233
# lat                               21991
# long                              17774
# host name                         13190
# last review                        2477
# house_rules                        1977
# price                              1151
# reviews per month                  1016
# number of reviews                   476
# availability 365                    437
# service fee                         231
# neighbourhood                       224
# minimum nights                      148
# calculated host listings count       78
# Construction year                    20
# neighbourhood group                   7
# review rate number                    5
# room type                             4
# cancellation_policy                   3
# host_identity_verified                2
# instant_bookable                      2
# country                               1
# country code                          1
# dtype: int64

# %%
df_Airbnb['reviews per month'].describe()
# Out:
# count    58491.000000
# mean         1.396071
# std          1.790129
# min          0.010000
# 25%          0.240000
# 50%          0.790000
# 75%          2.000000
# max         90.000000
# Name: reviews per month, dtype: float64

# %%
df_Airbnb['reviews per month'] = df_Airbnb['reviews per month'].fillna(0.79)

# %%
df_Airbnb[['cancellation_policy', 'country', 'NAME', 
    'instant_bookable', 'country code', 'neighbourhood', 'neighbourhood group',
    'host name', 'host_identity_verified']].mode()
# Out:
#   cancellation_policy        country                            NAME  \
# 0            moderate  United States  Water View King Bed Hotel Room
#
#   instant_bookable country code       neighbourhood neighbourhood group  \
# 0            False           US  Bedford-Stuyvesant           Manhattan
#
#   host name host_identity_verified
# 0   Michael            unconfirmed

# %%
# la columna no es relevante para predecir el precio 'cancellation_policy', 
# 'country' siempre se repite el mismo valor 'United States' al igual que la columna 'country code'
df_Airbnb = df_Airbnb.drop(['cancellation_policy', 'country'], axis=1)

# %%
df_Airbnb = df_Airbnb.drop(['country code'], axis = 1)

# %%
# haciendo una revision a cada columna del dataframe con el metodo '.value_counts()' 
# en busca de errores ortograficos que generen datos atipicos se tiene que 'neighbourhood group' 
# muestra dos valores erroneos 

df_Airbnb['neighbourhood group'].value_counts()
# Out:
# Manhattan        29573
# Brooklyn         27881
# Queens            9260
# Bronx             1911
# Staten Island      649
# brookln              1
# manhatan             1
# Name: neighbourhood group, dtype: int64

# %%
df_Airbnb['neighbourhood group'] = df_Airbnb['neighbourhood group'].replace({'manhatan': 'Manhattan', 'brookln': 'Brooklyn'})

# %%
# los valores nulos se remplazan por 'Empty'
df_Airbnb.loc[df_Airbnb.NAME.isnull(), 'NAME'] = 'Empty'

# %%
# se reemplaza los valores nulos de la columna 'host name' por 'Empty'
df_Airbnb['host name'] = df_Airbnb['host name'].fillna('Empty')

# %%
df_Airbnb['host_identity_verified'].isnull().sum()
# Out:
# 217

# %%
# los valores nulos se cambian por la media de su columna 'host_identity_verified'
df_Airbnb['host_identity_verified'] = df_Airbnb['host_identity_verified'].fillna('unconfirmed')

# %%
# ahora usaremos lat y long para para sustituir los valores faltates
# de la columnas 'neighbourhood' y 'neighbourhood group' para ello usaremos la siguiente libreria

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="MyApp")

# %%
# revismos primero cuantos valores nulos hay en 'neighbourhood'
df_Airbnb['neighbourhood'].isnull().value_counts()
# Out:
# False    69289
# True        16
# Name: neighbourhood, dtype: int64

# %%
# observemos mejor estos valores nulos 
df_Airbnb[df_Airbnb.neighbourhood.isnull()]
# Out:
#           id                                            NAME      host id  \
# 517  1286875             "The Oasis" on Bedford Williamsburg  30603782652
# 547  1303444                       STYLISH EAST VILLAGE FLAT   6825076306
# 553  1306758            Comfortable. Spacious. Private Room.  45534966158
# 575  1318909    2 Bed, 2 Bath Apartment on Central Park West  86633710982
# 589  1326641                           CBG Helps Haiti Rm #3  33952991254
# 613  1339896               Wonderfully inviting East Village  84560895335
# 624  1345971           Stylish Studio with exclusive Terrace  21547822804
# 633  1350942             Lower East Side/Chinatown 1 Bedroom  58408401042
# 643  1356465                        2BR  Apt - 20min to Soho  21192497123
# 670  1371377                Loft Suite @ The Box House Hotel  75427375884
# 678  1375795                Loft Suite @ The Box House Hotel  34416621424
# 681  1377452               Loft w/ Terrace @ Box House Hotel  77372797211
# 726  1402306                 Studio sublet in Hell's kitchen  42150054304
# 731  1405067               One bed suite with private garden    464927437
# 760  1421084  Spacious room on charming block in Greenpoint!  67988523719
# 770  1426607              Nights in White Satin in the Slope  54377094483
#
#     host_identity_verified host name neighbourhood group neighbourhood  \
# 517            unconfirmed     Lucas            Brooklyn           NaN
# 547               verified    Arnold           Manhattan           NaN
# 553            unconfirmed       Ned           Manhattan           NaN
# 575            unconfirmed    Arthur           Manhattan           NaN
# 589               verified     Jacob            Brooklyn           NaN
# 613               verified    Carter           Manhattan           NaN
# 624            unconfirmed      Cole           Manhattan           NaN
# 633               verified   Higgins           Manhattan           NaN
# 643               verified   Barrett            Brooklyn           NaN
# 670               verified      Gray            Brooklyn           NaN
# 678               verified     Smith            Brooklyn           NaN
# 681            unconfirmed   Higgins            Brooklyn           NaN
# 726               verified     Baker           Manhattan           NaN
# 731            unconfirmed     Myers           Manhattan           NaN
# 760               verified  Williams            Brooklyn           NaN
# 770            unconfirmed   Farrell            Brooklyn           NaN
#
#           lat      long instant_bookable  ...    price  service fee  \
# 517  40.71580 -73.95803              NaN  ...      NaN        $130
# 547  40.73089 -73.98195             True  ...    $749         $150
# 553  40.71300 -73.99752             True  ...    $613         $123
# 575  40.79816 -73.96190             True  ...    $892         $178
# 589  40.68012 -73.97847            False  ...    $793         $159
# 613  40.72709 -73.98274             True  ...    $486          $97
# 624  40.75348 -73.97065            False  ...    $417          $83
# 633  40.71693 -73.98948            False  ...  $1,148         $230
# 643  40.68016 -73.94878            False  ...    $938         $188
# 670  40.73641 -73.95330            False  ...    $104          $21
# 678  40.73693 -73.95316              NaN  ...    $914         $183
# 681  40.73783 -73.95259             True  ...    $528         $106
# 726  40.76217 -73.98411             True  ...    $831         $166
# 731  40.78304 -73.97447            False  ...    $624         $125
# 760  40.72723 -73.95728             True  ...    $745         $149
# 770  40.65992 -73.99042            False  ...  $1,111         $222
#
#     minimum nights number of reviews  last review  reviews per month  \
# 517            6.0               1.0   2016-01-01               0.02
# 547           30.0              25.0   2018-04-30               0.26
# 553            NaN             172.0   2019-07-02               1.84
# 575            2.0              45.0   2019-04-22               0.47
# 589            2.0              23.0   2018-09-15               0.24
# 613            1.0             109.0   2015-10-02               1.15
# 624           30.0             136.0   2019-06-19               1.45
# 633            5.0               8.0   2018-05-18               0.11
# 643            3.0               5.0   2017-07-09               0.05
# 670            3.0              24.0   2018-11-06               0.32
# 678            3.0              30.0   2019-07-03               0.32
# 681            3.0               3.0   2015-11-03               0.03
# 726            5.0               8.0   2015-01-08               0.09
# 731           30.0              16.0   2019-03-31               0.17
# 760            4.0               6.0   2019-04-21               0.07
# 770          180.0               1.0   2016-09-01               0.03
#
#     review rate number  calculated host listings count  availability 365  \
# 517                5.0                             1.0             266.0
# 547                4.0                             1.0              67.0
# 553                5.0                             2.0              63.0
# 575                4.0                             3.0               4.0
# 589                1.0                             6.0               NaN
# 613                2.0                             1.0             116.0
# 624                4.0                             1.0             272.0
# 633                3.0                             1.0              42.0
# 643                2.0                             1.0             408.0
# 670                4.0                            28.0             419.0
# 678                5.0                            28.0             296.0
# 681                2.0                            28.0             216.0
# 726                3.0                             1.0             322.0
# 731                4.0                             5.0              24.0
# 760                3.0                             1.0              20.0
# 770                4.0                             1.0             163.0
#
#                                            house_rules
# 517  1. No parties. 2. Respect the neighbors.  Nois...
# 547                                              Empty
# 553  Please be gentle with the furniture and applia...
# 575                                              Empty
# 589  Please remember that this is a residential bui...
# 613                                             #NAME?
# 624  Please remember that this is a residential bui...
# 633                                              Empty
# 643  Smoking is allowed on the patio only. No pets ...
# 670                                              Empty
# 678  House Rules Welcome to Boston-Furnished-Rental...
# 681  PLEASE  NOTE: • 6.25% MA State Sales Tax is al...
# 726  Please Note: This unit was just renovated in A...
# 731  No smoking, no pets, no parties please. Respec...
# 760                                              Empty
# 770                                              Empty
#
# [16 rows x 22 columns]

# %%
# crearemos una funcion que nos permita obtener los nombres de las ubicaciones específicas basándose en 
# las coordenadas geográficas.

def loc_from_coord(lat, long):
    location = geolocator.reverse(str(lat)+","+str(long))
    return location.raw['address'].get('road', '')

# %%
# y verificamos si la función trabaja bien

temp = df_Airbnb.loc[df_Airbnb.neighbourhood.isnull()].copy()
print(loc_from_coord(temp.iloc[2].lat, temp.iloc[2].long))
# Out:
# Henry Street

# %%
# ahora podremos sustituir los valores nulos de la columna 'neighbourhood'

idx = df_Airbnb.loc[df_Airbnb.neighbourhood.isnull()].index
df_Airbnb.loc[idx, 'neighbourhood'] = df_Airbnb.loc[idx].apply(lambda x: \
                                                loc_from_coord(x.lat, x.long), axis=1)

# %%
# verificamos 
df_Airbnb.loc[idx]
# Out:
#           id                                            NAME      host id  \
# 517  1286875             "The Oasis" on Bedford Williamsburg  30603782652
# 547  1303444                       STYLISH EAST VILLAGE FLAT   6825076306
# 553  1306758            Comfortable. Spacious. Private Room.  45534966158
# 575  1318909    2 Bed, 2 Bath Apartment on Central Park West  86633710982
# 589  1326641                           CBG Helps Haiti Rm #3  33952991254
# 613  1339896               Wonderfully inviting East Village  84560895335
# 624  1345971           Stylish Studio with exclusive Terrace  21547822804
# 633  1350942             Lower East Side/Chinatown 1 Bedroom  58408401042
# 643  1356465                        2BR  Apt - 20min to Soho  21192497123
# 670  1371377                Loft Suite @ The Box House Hotel  75427375884
# 678  1375795                Loft Suite @ The Box House Hotel  34416621424
# 681  1377452               Loft w/ Terrace @ Box House Hotel  77372797211
# 726  1402306                 Studio sublet in Hell's kitchen  42150054304
# 731  1405067               One bed suite with private garden    464927437
# 760  1421084  Spacious room on charming block in Greenpoint!  67988523719
# 770  1426607              Nights in White Satin in the Slope  54377094483
#
#     host_identity_verified host name neighbourhood group  \
# 517            unconfirmed     Lucas            Brooklyn
# 547               verified    Arnold           Manhattan
# 553            unconfirmed       Ned           Manhattan
# 575            unconfirmed    Arthur           Manhattan
# 589               verified     Jacob            Brooklyn
# 613               verified    Carter           Manhattan
# 624            unconfirmed      Cole           Manhattan
# 633               verified   Higgins           Manhattan
# 643               verified   Barrett            Brooklyn
# 670               verified      Gray            Brooklyn
# 678               verified     Smith            Brooklyn
# 681            unconfirmed   Higgins            Brooklyn
# 726               verified     Baker           Manhattan
# 731            unconfirmed     Myers           Manhattan
# 760               verified  Williams            Brooklyn
# 770            unconfirmed   Farrell            Brooklyn
#
#             neighbourhood       lat      long instant_bookable  ...    price  \
# 517         Driggs Avenue  40.71580 -73.95803              NaN  ...      NaN
# 547      East 14th Street  40.73089 -73.98195             True  ...    $749
# 553          Henry Street  40.71300 -73.99752             True  ...    $613
# 575      Manhattan Avenue  40.79816 -73.96190             True  ...    $892
# 589            5th Avenue  40.68012 -73.97847            False  ...    $793
# 613              Avenue A  40.72709 -73.98274             True  ...    $486
# 624      East 47th Street  40.75348 -73.97065            False  ...    $417
# 633          Grand Street  40.71693 -73.98948            False  ...  $1,148
# 643         Fulton Street  40.68016 -73.94878            False  ...    $938
# 670           Clay Street  40.73641 -73.95330            False  ...    $104
# 678  McGuinness Boulevard  40.73693 -73.95316              NaN  ...    $914
# 681  McGuinness Boulevard  40.73783 -73.95259             True  ...    $528
# 726              Broadway  40.76217 -73.98411             True  ...    $831
# 731       Columbus Avenue  40.78304 -73.97447            False  ...    $624
# 760       Franklin Street  40.72723 -73.95728             True  ...    $745
# 770           21st Street  40.65992 -73.99042            False  ...  $1,111
#
#      service fee minimum nights number of reviews  last review  \
# 517        $130             6.0               1.0   2016-01-01
# 547        $150            30.0              25.0   2018-04-30
# 553        $123             NaN             172.0   2019-07-02
# 575        $178             2.0              45.0   2019-04-22
# 589        $159             2.0              23.0   2018-09-15
# 613         $97             1.0             109.0   2015-10-02
# 624         $83            30.0             136.0   2019-06-19
# 633        $230             5.0               8.0   2018-05-18
# 643        $188             3.0               5.0   2017-07-09
# 670         $21             3.0              24.0   2018-11-06
# 678        $183             3.0              30.0   2019-07-03
# 681        $106             3.0               3.0   2015-11-03
# 726        $166             5.0               8.0   2015-01-08
# 731        $125            30.0              16.0   2019-03-31
# 760        $149             4.0               6.0   2019-04-21
# 770        $222           180.0               1.0   2016-09-01
#
#      reviews per month review rate number  calculated host listings count  \
# 517               0.02                5.0                             1.0
# 547               0.26                4.0                             1.0
# 553               1.84                5.0                             2.0
# 575               0.47                4.0                             3.0
# 589               0.24                1.0                             6.0
# 613               1.15                2.0                             1.0
# 624               1.45                4.0                             1.0
# 633               0.11                3.0                             1.0
# 643               0.05                2.0                             1.0
# 670               0.32                4.0                            28.0
# 678               0.32                5.0                            28.0
# 681               0.03                2.0                            28.0
# 726               0.09                3.0                             1.0
# 731               0.17                4.0                             5.0
# 760               0.07                3.0                             1.0
# 770               0.03                4.0                             1.0
#
#      availability 365                                        house_rules
# 517             266.0  1. No parties. 2. Respect the neighbors.  Nois...
# 547              67.0                                              Empty
# 553              63.0  Please be gentle with the furniture and applia...
# 575               4.0                                              Empty
# 589               NaN  Please remember that this is a residential bui...
# 613             116.0                                             #NAME?
# 624             272.0  Please remember that this is a residential bui...
# 633              42.0                                              Empty
# 643             408.0  Smoking is allowed on the patio only. No pets ...
# 670             419.0                                              Empty
# 678             296.0  House Rules Welcome to Boston-Furnished-Rental...
# 681             216.0  PLEASE  NOTE: • 6.25% MA State Sales Tax is al...
# 726             322.0  Please Note: This unit was just renovated in A...
# 731              24.0  No smoking, no pets, no parties please. Respec...
# 760              20.0                                              Empty
# 770             163.0                                              Empty
#
# [16 rows x 22 columns]

# %%
# ahora haremos lo mismo para la columna 'neighbourhood group' creando una funcion de coordenadas 
def neigh_from_coord(lat,long):
    location = geolocator.reverse(str(lat)+","+str(long))
    return location.raw['address'].get('suburb', '')

# %%
# observamos primero los valores nulos
df_Airbnb[df_Airbnb['neighbourhood group'].isnull()].head()
# Out:
#          id                                    NAME      host id  \
# 74  1042206         HARLEM, NEW YORK WELCOMES YOU!!  98195975718
# 75  1042759                   BLUE TRIM GUEST HOUSE   4726877402
# 76  1043311  Charming East Village One Bedroom Flat  74322993447
# 77  1043863                          Manhattan Room  11468499446
# 78  1044415                   Little King of Queens  68599531533
#
#    host_identity_verified host name neighbourhood group       neighbourhood  \
# 74            unconfirmed    Violet                 NaN  Washington Heights
# 75            unconfirmed    Audrey                 NaN        Clinton Hill
# 76               verified    Violet                 NaN        East Village
# 77               verified     Sofia                 NaN     Upper East Side
# 78            unconfirmed   Melanie                 NaN            Woodside
#
#          lat      long instant_bookable  ...  price  service fee  \
# 74  40.83139 -73.94095             True  ...  $571         $114
# 75  40.68346 -73.96374             True  ...  $398          $80
# 76  40.72828 -73.98801            False  ...  $618         $124
# 77  40.76865 -73.95058            False  ...  $116          $23
# 78  40.75038 -73.90334             True  ...   $54          $11
#
#    minimum nights number of reviews  last review  reviews per month  \
# 74            2.0              49.0   2019-06-18               1.60
# 75            2.0             105.0   2019-06-26               0.92
# 76            5.0              21.0   2019-01-02               0.20
# 77            1.0             142.0   2019-07-06               1.50
# 78           30.0              25.0   2019-06-14               0.22
#
#    review rate number  calculated host listings count  availability 365  \
# 74                2.0                             2.0               NaN
# 75                1.0                             1.0               NaN
# 76                4.0                             1.0               NaN
# 77                4.0                             1.0               NaN
# 78                2.0                             1.0               NaN
#
#                                           house_rules
# 74  The usual courtesies apply: - No smoking - No ...
# 75  Shoes off please Cat can go in or out as he de...
# 76                                   no smoking quiet
# 77  I'm a semi kosher vegetarian which means that ...
# 78  No Street Shoes allowed in House. No cooking K...
#
# [5 rows x 22 columns]

# %%
# verificamos 
idx2 = df_Airbnb.loc[df_Airbnb['neighbourhood group'].isnull()].index
print(neigh_from_coord(df_Airbnb.loc[idx2].iloc[4].lat, df_Airbnb.loc[idx2].iloc[4].long))
# Out:
# Queens County

# %%
# luego sustituimos los datos nulos de la columna 'neighbourhood group'
df_Airbnb.loc[idx2, 'neighbourhood group'] = df_Airbnb.loc[idx2].apply(lambda x: \
                                                neigh_from_coord(x.lat, x.long), axis=1)

# %%
#verificamos los cambios a la columna 'neighbourhood group'
df_Airbnb.loc[idx2].head()
# Out:
#          id                                    NAME      host id  \
# 74  1042206         HARLEM, NEW YORK WELCOMES YOU!!  98195975718
# 75  1042759                   BLUE TRIM GUEST HOUSE   4726877402
# 76  1043311  Charming East Village One Bedroom Flat  74322993447
# 77  1043863                          Manhattan Room  11468499446
# 78  1044415                   Little King of Queens  68599531533
#
#    host_identity_verified host name neighbourhood group       neighbourhood  \
# 74            unconfirmed    Violet           Manhattan  Washington Heights
# 75            unconfirmed    Audrey            Brooklyn        Clinton Hill
# 76               verified    Violet           Manhattan        East Village
# 77               verified     Sofia           Manhattan     Upper East Side
# 78            unconfirmed   Melanie       Queens County            Woodside
#
#          lat      long instant_bookable  ...  price  service fee  \
# 74  40.83139 -73.94095             True  ...  $571         $114
# 75  40.68346 -73.96374             True  ...  $398          $80
# 76  40.72828 -73.98801            False  ...  $618         $124
# 77  40.76865 -73.95058            False  ...  $116          $23
# 78  40.75038 -73.90334             True  ...   $54          $11
#
#    minimum nights number of reviews  last review  reviews per month  \
# 74            2.0              49.0   2019-06-18               1.60
# 75            2.0             105.0   2019-06-26               0.92
# 76            5.0              21.0   2019-01-02               0.20
# 77            1.0             142.0   2019-07-06               1.50
# 78           30.0              25.0   2019-06-14               0.22
#
#    review rate number  calculated host listings count  availability 365  \
# 74                2.0                             2.0               NaN
# 75                1.0                             1.0               NaN
# 76                4.0                             1.0               NaN
# 77                4.0                             1.0               NaN
# 78                2.0                             1.0               NaN
#
#                                           house_rules
# 74  The usual courtesies apply: - No smoking - No ...
# 75  Shoes off please Cat can go in or out as he de...
# 76                                   no smoking quiet
# 77  I'm a semi kosher vegetarian which means that ...
# 78  No Street Shoes allowed in House. No cooking K...
#
# [5 rows x 22 columns]

# %%
df_Airbnb['neighbourhood group'].value_counts()
# Out:
# Manhattan        29587
# Brooklyn         27895
# Queens            9260
# Bronx             1911
# Staten Island      649
# Queens County        2
# The Bronx            1
# Name: neighbourhood group, dtype: int64

# %%
df_Airbnb['neighbourhood group'] = df_Airbnb['neighbourhood group'].replace({'The Bronx': 'Bronx'})

# %%
# ahora verificamos la cantidad de dato nulos en la columna 'lat'
df_Airbnb.lat.isnull().value_counts()
# Out:
# False    69297
# True         8
# Name: lat, dtype: int64

# %%
# observamos los datos
df_Airbnb.loc[df_Airbnb.lat.isnull()]
# Out:
#           id                                   NAME      host id  \
# 779  1431578  Large, furnished room in a 2 bedroom!  20368956893
# 785  1434892      Authentic NY Charming Artist Loft  66486085219
# 799  1442624         Huge room with private balcony  69386945815
# 814  1450908    Decorators 5-Star Flat West Village  33280739304
# 843  1466925     Nice Private Room Beauty in Queens  15305733205
# 885  1490122            Cute Room in Historic Loft!  42267829819
# 926  1512766        21 day Chelsea Apartment rental  10876728736
# 986  1545904         New York City for All Seasons!  26437872336
#
#     host_identity_verified host name neighbourhood group      neighbourhood  \
# 779            unconfirmed    Gibson            Brooklyn      Crown Heights
# 785            unconfirmed    Bailey            Brooklyn         Greenpoint
# 799               verified      Hunt           Manhattan       East Village
# 814               verified    Watson           Manhattan       West Village
# 843               verified   Roberts              Queens           Elmhurst
# 885            unconfirmed     Jones            Brooklyn         Greenpoint
# 926            unconfirmed     Owens           Manhattan  Flatiron District
# 986            unconfirmed   Douglas           Manhattan    Upper West Side
#
#      lat  long instant_bookable  ...    price  service fee minimum nights  \
# 779  NaN   NaN            False  ...    $539         $108             1.0
# 785  NaN   NaN            False  ...  $1,058         $212             5.0
# 799  NaN   NaN            False  ...    $506         $101             6.0
# 814  NaN   NaN             True  ...    $381          $76            20.0
# 843  NaN   NaN             True  ...    $224          $45             1.0
# 885  NaN   NaN             True  ...    $524         $105            14.0
# 926  NaN   NaN            False  ...    $623         $125            21.0
# 986  NaN   NaN             True  ...    $413          $83             1.0
#
#     number of reviews  last review  reviews per month review rate number  \
# 779               1.0   2017-03-18               0.04                2.0
# 785              14.0   2019-06-19               0.16                5.0
# 799               1.0   2013-05-06               0.01                1.0
# 814             157.0   2016-08-11               1.71                4.0
# 843              63.0   2019-05-18               0.89                3.0
# 885              22.0   2019-05-02               0.25                1.0
# 926               0.0   2019-06-14               0.79                2.0
# 986              25.0   2013-06-22               0.28                2.0
#
#      calculated host listings count  availability 365  \
# 779                             1.0              41.0
# 785                             1.0             226.0
# 799                             1.0             240.0
# 814                             1.0              61.0
# 843                             2.0              70.0
# 885                             1.0             266.0
# 926                             1.0             104.0
# 986                             1.0             259.0
#
#                                            house_rules
# 779  - Weekly and monthly prices are much lower - P...
# 785  We live and let live - hoping that you'd be re...
# 799  Expect respect for the family and the space--t...
# 814  Please keep it clean, thats all we really ask ...
# 843                                              Empty
# 885  Pets are cool (just clean up after them!), smo...
# 926                                              Empty
# 986                                 No Smoking No Pets
#
# [8 rows x 22 columns]

# %%
# obtenemos los indices de los datos faltantes de la columna 'lat'
idx3 = df_Airbnb.loc[df_Airbnb.lat.isnull()].index
idx3
# Out:
# Int64Index([779, 785, 799, 814, 843, 885, 926, 986], dtype='int64')

# %%
# ahora haremos el proceso inverso por medio de la locación obtendremos 
# los datos  de la latitud y  longitud, para ello crearemos dos funciones
# una para la latitud y longitud

def lat_from_loc(loc):
    location = geolocator.geocode(loc)
    return location.latitude

def long_from_loc(loc):
    location = geolocator.geocode(loc)
    return location.longitude

# %%
print(lat_from_loc(df_Airbnb.loc[idx3].iloc[0].neighbourhood), long_from_loc(df_Airbnb.loc[idx3].iloc[0].neighbourhood))
# Out:
# 40.667471 -73.9435662

# %%
# ahora queda sustituir los datos de lat y long usando neighbourhood and 
# neighbourhood group

df_Airbnb.loc[idx3, 'lat'] = df_Airbnb.loc[idx3].apply(lambda x: lat_from_loc(x.neighbourhood+', '+x['neighbourhood group']), axis=1)
df_Airbnb.loc[idx3, 'long'] = df_Airbnb.loc[idx3].apply(lambda x: long_from_loc(x.neighbourhood+', '+x['neighbourhood group']), axis=1)

# %%
df_Airbnb.loc[idx3]
# Out:
#           id                                   NAME      host id  \
# 779  1431578  Large, furnished room in a 2 bedroom!  20368956893
# 785  1434892      Authentic NY Charming Artist Loft  66486085219
# 799  1442624         Huge room with private balcony  69386945815
# 814  1450908    Decorators 5-Star Flat West Village  33280739304
# 843  1466925     Nice Private Room Beauty in Queens  15305733205
# 885  1490122            Cute Room in Historic Loft!  42267829819
# 926  1512766        21 day Chelsea Apartment rental  10876728736
# 986  1545904         New York City for All Seasons!  26437872336
#
#     host_identity_verified host name neighbourhood group      neighbourhood  \
# 779            unconfirmed    Gibson            Brooklyn      Crown Heights
# 785            unconfirmed    Bailey            Brooklyn         Greenpoint
# 799               verified      Hunt           Manhattan       East Village
# 814               verified    Watson           Manhattan       West Village
# 843               verified   Roberts              Queens           Elmhurst
# 885            unconfirmed     Jones            Brooklyn         Greenpoint
# 926            unconfirmed     Owens           Manhattan  Flatiron District
# 986            unconfirmed   Douglas           Manhattan    Upper West Side
#
#            lat       long instant_bookable  ...    price  service fee  \
# 779  40.667471 -73.943566            False  ...    $539         $108
# 785  40.723713 -73.950971            False  ...  $1,058         $212
# 799  40.729269 -73.987361            False  ...    $506         $101
# 814  40.734186 -74.005580             True  ...    $381          $76
# 843  40.736580 -73.878393             True  ...    $224          $45
# 885  40.723713 -73.950971             True  ...    $524         $105
# 926  40.741072 -73.989653            False  ...    $623         $125
# 986  40.787045 -73.975416             True  ...    $413          $83
#
#     minimum nights number of reviews  last review  reviews per month  \
# 779            1.0               1.0   2017-03-18               0.04
# 785            5.0              14.0   2019-06-19               0.16
# 799            6.0               1.0   2013-05-06               0.01
# 814           20.0             157.0   2016-08-11               1.71
# 843            1.0              63.0   2019-05-18               0.89
# 885           14.0              22.0   2019-05-02               0.25
# 926           21.0               0.0   2019-06-14               0.79
# 986            1.0              25.0   2013-06-22               0.28
#
#     review rate number  calculated host listings count  availability 365  \
# 779                2.0                             1.0              41.0
# 785                5.0                             1.0             226.0
# 799                1.0                             1.0             240.0
# 814                4.0                             1.0              61.0
# 843                3.0                             2.0              70.0
# 885                1.0                             1.0             266.0
# 926                2.0                             1.0             104.0
# 986                2.0                             1.0             259.0
#
#                                            house_rules
# 779  - Weekly and monthly prices are much lower - P...
# 785  We live and let live - hoping that you'd be re...
# 799  Expect respect for the family and the space--t...
# 814  Please keep it clean, thats all we really ask ...
# 843                                              Empty
# 885  Pets are cool (just clean up after them!), smo...
# 926                                              Empty
# 986                                 No Smoking No Pets
#
# [8 rows x 22 columns]

# %%
# ahora verificamos los datos nulos del dataframe
df_Airbnb.isnull().sum().sort_values(ascending=False)
# Out:
# availability 365                  438
# minimum nights                    363
# price                             245
# service fee                       241
# review rate number                239
# Construction year                 190
# number of reviews                 152
# calculated host listings count    144
# instant_bookable                   86
# reviews per month                   0
# last review                         0
# id                                  0
# NAME                                0
# room type                           0
# long                                0
# lat                                 0
# neighbourhood                       0
# neighbourhood group                 0
# host name                           0
# host_identity_verified              0
# host id                             0
# house_rules                         0
# dtype: int64

# %%
df_Airbnb['availability 365'].describe()
# Out:
# count    68867.000000
# mean       153.350821
# std        134.831895
# min        -10.000000
# 25%         17.000000
# 50%        127.000000
# 75%        282.000000
# max        426.000000
# Name: availability 365, dtype: float64

# %%
df_Airbnb['availability 365'] = df_Airbnb['availability 365'].fillna(127)

# %%
df_Airbnb['minimum nights'].describe()
# Out:
# count    68942.000000
# mean         8.717937
# std         34.627155
# min      -1223.000000
# 25%          1.000000
# 50%          3.000000
# 75%          6.000000
# max       5645.000000
# Name: minimum nights, dtype: float64

# %%
df_Airbnb['minimum nights'] = df_Airbnb['minimum nights'].fillna(3)

# %%
# vemos que el precio tiene 245 datos nulos 
# pero primero para hacer las mediciones correpondientes vamos a convertir la columna precio en tipo de dato numerico

def convertir_a_float(valor):
    try:
        # Si el valor ya es un número, simplemente devolverlo como float
        return float(valor)
    except (ValueError, TypeError):
        # Si hay un error en la conversión, o el valor no es un tipo numérico, tratar de limpiar y convertir
        try:
            return float(str(valor).replace('$', '').replace(',', ''))
        except ValueError:
            # Si hay un segundo error, retornar NaN
            return float('nan')

# %%
# ahora aplicamos la funcion convertir_a_float
df_Airbnb['price'] = df_Airbnb['price'].apply(convertir_a_float)

# %%
df_Airbnb['price'].describe()
# Out:
# count    69060.000000
# mean       624.736070
# std        331.745841
# min         50.000000
# 25%        338.000000
# 50%        624.000000
# 75%        912.000000
# max       1200.000000
# Name: price, dtype: float64

# %%
#ahora sustituimos los valores nulos por el promedio 
df_Airbnb['price'] = df_Airbnb['price'].fillna(df_Airbnb['price'].mean())

# %%
# oh no, esta columna 'service fee' es muy parecida a la columna precio 
# por lo que aplicaremos la misma funcion convertir_a_float 
df_Airbnb['service fee'] = df_Airbnb['service fee'].apply(convertir_a_float)

# %%
df_Airbnb['service fee'].describe()
# Out:
# count    69064.000000
# mean       124.894026
# std         66.338238
# min         10.000000
# 25%         68.000000
# 50%        125.000000
# 75%        182.000000
# max        240.000000
# Name: service fee, dtype: float64

# %%
df_Airbnb['service fee']
# Out:
# 0         193.0
# 1          28.0
# 2         124.0
# 3          74.0
# 4          41.0
#           ...
# 102046      NaN
# 102047      NaN
# 102048      NaN
# 102049      NaN
# 102050      NaN
# Name: service fee, Length: 69305, dtype: float64

# %%
# sustituimos los valores nulos por el promedio 
df_Airbnb['service fee'].fillna(df_Airbnb['service fee'].mean(), inplace = True)

# %%
df_Airbnb.isnull().sum().sort_values(ascending = False)
# Out:
# review rate number                239
# Construction year                 190
# number of reviews                 152
# calculated host listings count    144
# instant_bookable                   86
# price                               0
# availability 365                    0
# reviews per month                   0
# last review                         0
# minimum nights                      0
# service fee                         0
# id                                  0
# NAME                                0
# room type                           0
# long                                0
# lat                                 0
# neighbourhood                       0
# neighbourhood group                 0
# host name                           0
# host_identity_verified              0
# host id                             0
# house_rules                         0
# dtype: int64

# %%
df_Airbnb[['review rate number', 'Construction year', 'number of reviews', 'calculated host listings count', 'instant_bookable']].dtypes
# Out:
# review rate number                float64
# Construction year                 float64
# number of reviews                 float64
# calculated host listings count    float64
# instant_bookable                   object
# dtype: object

# %%
df_Airbnb[['review rate number', 'Construction year', 'number of reviews', 'calculated host listings count']].median()
# Out:
# review rate number                   3.0
# Construction year                 2012.0
# number of reviews                    7.0
# calculated host listings count       1.0
# dtype: float64

# %%
medians = df_Airbnb[['review rate number', 'Construction year', 'number of reviews', 'calculated host listings count']].median()

df_Airbnb[['review rate number', 'Construction year', 'number of reviews', 'calculated host listings count']] = df_Airbnb[['review rate number', 'Construction year', 'number of reviews', 'calculated host listings count']].fillna(medians)

# %%
df_Airbnb['instant_bookable'].value_counts()
# Out:
# False    34867
# True     34352
# Name: instant_bookable, dtype: int64

# %%
df_Airbnb['instant_bookable'].fillna(False, inplace = True)

# %%
df_Airbnb.columns = df_Airbnb.columns.str.lower().str.replace(' ','_')
df_Airbnb.head(1)
# Out:
#         id                                name      host_id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
#
#   host_identity_verified host_name neighbourhood_group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
#
#         lat      long  instant_bookable  ...  price  service_fee  \
# 0  40.64749 -73.97237             False  ...  966.0        193.0
#
#    minimum_nights  number_of_reviews  last_review  reviews_per_month  \
# 0            10.0                9.0   2021-10-19               0.21
#
#   review_rate_number  calculated_host_listings_count  availability_365  \
# 0                4.0                             6.0             286.0
#
#                                          house_rules
# 0  Clean up and treat the home the way you'd like...
#
# [1 rows x 22 columns]
